# %% [markdown]
# # DataFrame 布尔索引

# %%
import pandas as pd
df = pd.DataFrame(
    data = {"id" : [101,102,103,104],"name" :["赵四","广坤","小宝","刘能"],"age" :[22,23,34,45] }
)
print(df)
# Out:
#     id name  age
# 0  101   赵四   22
# 1  102   广坤   23
# 2  103   小宝   34
# 3  104   刘能   45

# %%
print(df["age"] > 25)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: age, dtype: bool

# %%
print(df[df["age"] > 25]) # 使用布尔索引获取数据 只保留True的 False不要
# Out:
#     id name  age
# 2  103   小宝   34
# 3  104   刘能   45
