# %% [markdown]
# # 创建ndarray数组的方式

# %%
import numpy as np


arr1 = np.matrix("1 2 3")
arr1
# Out:
# matrix([[1, 2, 3]])

# %%
arr2 = np.matrix("1 2 3 ; 4 5 6")
arr2
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6]])
