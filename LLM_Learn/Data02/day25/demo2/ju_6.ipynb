# %% [markdown]
# # 比较函数 最终的结果为布尔类型

# %%
import numpy as np

arr1 = np.array([1,2,3,4])
arr1
# Out:
# array([1, 2, 3, 4])

# %%
print(np.any(arr1 > 3)) # 数组中的元素 有一个满足 则返回True
# Out:
# True

# %%
print(np.all(arr1 > 3)) # 数组中的元素 每一个都满足条件才返回True
# Out:
# False
