# %% [markdown]
# # 去重函数 会去除重复元素 并且升序排列  返回一个一维数组

# %%
import numpy as np

arr1 = np.random.randint(1,10,(3,3))
arr1
# Out:
# array([[4, 9, 2],
#        [7, 3, 2],
#        [3, 5, 2]], dtype=int32)

# %%
np.unique(arr1) # 去除重复元素 并且排序
# Out:
# array([2, 3, 4, 5, 7, 9], dtype=int32)
